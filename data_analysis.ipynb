# %%
import pandas as pd

# %%
pd.read_csv('ANNUAL_Temp_IND.csv')
# Out:
#        YEAR  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 0    1901.0   25.42    20.11    27.64    28.16     23.1
# 1    1902.0   25.42    20.88    27.96    27.98    22.51
# 2    1903.0   25.01    19.99    27.02       28    22.33
# 3    1904.0   24.93    19.76    27.23    27.57    22.56
# 4    1905.0   24.84    18.36    26.38     28.2    23.13
# ..      ...     ...      ...      ...      ...      ...
# 118  2019.0   25.86    20.71       28     28.6    23.49
# 119  2020.0   25.78    20.79    27.58    28.45    23.75
# 120  2021.0   25.93    21.43    27.97    28.36    23.66
# 121     NaN     NaN      NaN      NaN      NaN      NaN
# 122     NaN  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
#
# [123 rows x 6 columns]
# WARNING: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %%
df = pd.read_csv('ANNUAL_Temp_IND.csv')

# %%
df_sorted = df.sort_values(by='ANNUAL')
display(df_sorted)
# Out:
#        YEAR  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 16   1917.0   24.54    20.16    26.16     27.3    22.14
# 44   1945.0   24.69    18.88    27.05       28    21.79
# 70   1971.0   24.83    20.13    26.96    27.31    22.52
# 74   1975.0   24.84     19.8    27.42    27.33    22.29
# 42   1943.0   24.84    19.67    26.94    27.59    22.53
# ..      ...     ...      ...      ...      ...      ...
# 116  2017.0   26.04    21.37     28.2    28.39    23.84
# 108  2009.0   26.05    21.59    28.12    28.55    23.61
# 115  2016.0    26.2     21.8    28.64    28.35    23.84
# 122     NaN  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 121     NaN     NaN      NaN      NaN      NaN      NaN
#
# [123 rows x 6 columns]

# %%
df_years_annual = df_cleaned[['YEAR', 'ANNUAL']]
display(df_years_annual)
# Out:
#        YEAR ANNUAL
# 0    1901.0  25.42
# 1    1902.0  25.42
# 2    1903.0  25.01
# 3    1904.0  24.93
# 4    1905.0  24.84
# ..      ...    ...
# 116  2017.0  26.04
# 117  2018.0   25.9
# 118  2019.0  25.86
# 119  2020.0  25.78
# 120  2021.0  25.93
#
# [121 rows x 2 columns]

# %%
df_years_annual_sorted = df_years_annual.sort_values(by='ANNUAL')
display(df_years_annual_sorted)
# Out:
#        YEAR ANNUAL
# 16   1917.0  24.54
# 44   1945.0  24.69
# 70   1971.0  24.83
# 74   1975.0  24.84
# 42   1943.0  24.84
# ..      ...    ...
# 120  2021.0  25.93
# 109  2010.0  26.03
# 116  2017.0  26.04
# 108  2009.0  26.05
# 115  2016.0   26.2
#
# [121 rows x 2 columns]

# %%
years_above_25 = df_years_annual[df_years_annual['ANNUAL'] >= 25]
display(years_above_25)
# Out:
#        YEAR  ANNUAL  Decade
# 0    1901.0   25.42  1900.0
# 1    1902.0   25.42  1900.0
# 2    1903.0   25.01  1900.0
# 5    1906.0   25.18  1900.0
# 6    1907.0   25.02  1900.0
# ..      ...     ...     ...
# 116  2017.0   26.04  2010.0
# 117  2018.0   25.90  2010.0
# 118  2019.0   25.86  2010.0
# 119  2020.0   25.78  2020.0
# 120  2021.0   25.93  2020.0
#
# [103 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 7))
plt.bar(df_years_annual['YEAR'], df_years_annual['ANNUAL'])
plt.xlabel('Year')
plt.ylabel('Annual Temperature')
plt.title('Annual Temperature for Every Year')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
